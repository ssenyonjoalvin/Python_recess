# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns 

df = pd.read_csv("crop.csv")
print(df)

print(df.isna().sum())
print(df.duplicated())

# N is the nitrogen
# K patassium
# p phosphorous
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
# [2200 rows x 8 columns]
# N              0
# P              0
# K              0
# temperature    0
# ...

# %%
print(df.describe())
# Out:
#                  N            P            K  temperature     humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     50.551818    53.362727    48.149091    25.616244    71.481779
# std      36.917334    32.985883    50.647931     5.063749    22.263812
# min       0.000000     5.000000     5.000000     8.825675    14.258040
# 25%      21.000000    28.000000    20.000000    22.769375    60.261953
# 50%      37.000000    51.000000    32.000000    25.598693    80.473146
# 75%      84.250000    68.000000    49.000000    28.561654    89.948771
# max     140.000000   145.000000   205.000000    43.675493    99.981876
#
#                 ph     rainfall
# count  2200.000000  2200.000000
# mean      6.469480   103.463655
# std       0.773938    54.958389
# min       3.504752    20.211267
# 25%       5.971693    64.551686
# 50%       6.425045    94.867624
# 75%       6.923643   124.267508
# max       9.935091   298.560117

# %%
# check way for null vaule 
sns.heatmap(df.isnull(),cmap='coolwarm')
plt.show()

# %%
# distribution of temperature
print()

# %%
sns.histplot(df['temperature'],color='yellow', bins=30,kde=True)
plt.title('Temperature Distribution')
plt.show()
# Out:
# /home/ssenyonjoalvin/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(df['ph'],color='yellow', bins=30,kde=True)
plt.title('ph Distribution')
plt.show()
# Out:
# /home/ssenyonjoalvin/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# check if the dataset is balanced or not

sns.countplot(y='label',data=df, )
plt.title('Label Distribution')
plt.show()

# %%
sns.boxplot(y="label",x='ph',data=df,palette='plasma_r')
plt.title('Phosphorous level')
plt.show()

# %%
# phosphorous  level
sns.boxplot(y='label',x='P',data=df[df['rainfall']>150])
plt.title('Phosphorous level')
plt.show()

# %%
# Visulation correlation
sns.heatmap(X.corr(),annot=True, cmap="coolwarm")
plt.title('Correlation Heatmap')
plt.show()

# %%
# Correlation, relationship between columns
c =df.label.astype('category')
targets = dict(enumerate(c.cat.categories))
df['target'] = c.cat.codes

y = df.target
X = df[['N', 'P', 'temperature','humidity','ph','rainfall']]

sns.heatmap(X.corr())
plt.title("Correlation")
plt.show()
